# %% [markdown]
# <a href="https://colab.research.google.com/github/masterinfo/COURS_ELEARNING/blob/master/PCA_Factor_analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 5 - Dimensionality Reduction Methods
#
# ## Segment 1 - Explanatory factor analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

import sklearn
from sklearn.decomposition import FactorAnalysis

from sklearn import datasets

# %% [markdown]
# ### Factor analysis on iris dataset

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iris =  datasets.load_iris()

X = iris.data
variable_names = iris.feature_names

X[0:10,]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]])

# %%
X[0:15,]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2]])

# %% [markdown]
# What is meant by factor analysis?
# What is Factor Analysis? | TIBCO Software
# Factor analysis is a statistical technique that reduces a set of variables by extracting all their commonalities into a smaller number of factors. It can also be called data reduction. When observing vast numbers of variables, some common patterns emerge, which are known as factors.

# %% [markdown]
# What is Factor Analysis?
#
# Factor analysis is a statistical technique that reduces a set of variables by extracting all their commonalities into a smaller number of factors. It can also be called data reduction.
#
# When observing vast numbers of variables, some common patterns emerge, which are known as factors. These serve as an index of all the variables involved and can be utilized for later analysis.

# %%
factor = FactorAnalysis().fit(X)

DF = pd.DataFrame(factor.components_, columns=variable_names)
print(DF)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.706989         -0.158005           1.654236           0.70085
# 1           0.115161          0.159635          -0.044321          -0.01403
# 2          -0.000000          0.000000           0.000000           0.00000
# 3          -0.000000          0.000000           0.000000          -0.00000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# factor one is highly influential on sepal length, petal length, and petal width of irises. Factor two has no high loadings on any of the variables here. Because of that, you can't interpret much and you should drop the factor throughout the remainder of your evaluation. From this analysis, we have isolated one underlying latent variable that influences the sepal length, petal length, and petal width. Next, we will look at principal component analysis.
